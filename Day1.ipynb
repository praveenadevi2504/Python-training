# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenadevi2504/Python-training/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keyword
print("standard keyword=",len(keyword.kwlist))
print("soft keyword=",keyword.softkwlist)
print("All keyword=",keyword.kwlist)
x=5
y="Python"
z=5.0
print(x)
print(y)
print(z)
print(type(x))
print(type(y))
print(type(z))
y1=2
print(y1)
print(type(y1))
y1=int(2)
y2=float(y1)
print(y2)
y3=str(y1)
print(y3)
y4=bool(y3)
print(y4)
# Out:
# standard keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# All keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 5
# Python
# 5.0
# <class 'int'>
# <class 'str'>
# <class 'float'>
# 2
# <class 'int'>
# 2.0
# 2
# True
